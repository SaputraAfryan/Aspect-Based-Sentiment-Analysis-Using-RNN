# %% [markdown]
# # Library

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from gensim.models import FastText
from imblearn.over_sampling import SMOTE

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from keras.utils.np_utils import to_categorical
from keras.models import load_model, Model, Sequential
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Dense, Embedding, SimpleRNN, Dropout

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# # Preprocessing
# ### Load Data

# %%
df = pd.read_pickle(r'C:\Users\HP Victus 16\Documents\TA_Code\Preprocessing\preprocessed_df.pkl')
df = pd.DataFrame(df[['detokenize','akting']])
df.head()
# Out:
#                                           detokenize  akting
# 0  the desperate hour lakewood salah cerita suara...       1
# 1  edisi males review singkat tonton libur dp des...       1
# 2  plot utama orang deserter pursuit buru wamil j...       1
# 3  film hereditary horror thrill midsommar gatau ...       0
# 4  batman manusiawi tarung nya sadis scene pursui...       0

# %%
reviews = df['detokenize']
label = df['akting']

# %% [markdown]
# # Variables

# %%
MAX_FEATURES = 1000
test_size_split = 0.3

# %% [markdown]
# # Feature Extraction

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features = MAX_FEATURES)

tfidf = vectorizer.fit_transform(reviews.astype(str))

# %% [markdown]
# # SMOTE

# %%
smote = SMOTE()

x_smote, y_smote = smote.fit_resample(tfidf, label)

# %% [markdown]
# # Split Data

# %%
x_train, x_test, y_train, y_test = (
    train_test_split(x_smote, 
                     y_smote, 
                     test_size=test_size_split, 
                     stratify = y_smote, 
                     random_state=42)
)

print(f'Train\t| X shape: {x_train.shape}\tY shape: {y_train.shape}')
print(f'Test\t| X shape: {x_test.shape}\tY shape: {y_test.shape}')
# Out:
# Train	| X shape: (28917, 1000)	Y shape: (28917,)
# Test	| X shape: (12393, 1000)	Y shape: (12393,)

# %% [markdown]
# # Feature Expansion

# %%
# Load trained fasttext model
model_exp = FastText.load(r'C:\Users\HP Victus 16\Documents\TA_Code\Corpus_FastText\fasttext_news_tweet.model').wv

# %%
def feature_expansion(df, feature):
    for col in tqdm(df.columns): #loop per kolom
        try: 
            sim_word = model_exp.similar_by_word(col, topn = 40) #Mencari similarity berdasarkan nilai n
        except:
            sim_word = []
        if sim_word != []: #jika similarity tidak kosong
            for term in [sim_word[i][0] for i in range(len(sim_word))]: #loop per-word yang ada di Similarity
                if term in feature:
                    #untuk semua kolom yang mempunyai nilai 0 di kolom, tetapi mempunyai nilai yang bukan 0 pada kolom term
                    #nilainya diganti dengan nilai kolom term yang mempunyai nilai bukan 0
                    df[col][(df[col]==0) & (df[term]!=0)] = df[term][(df[col]==0) & (df[term]!=0)]
    return df

# %%
feature_ext = vectorizer.get_feature_names_out()

df_x_train = pd.DataFrame(x_train.todense(), columns = feature_ext)
df_x_test = pd.DataFrame(x_test.todense(), columns = feature_ext)

df_x_train_exp = feature_expansion(df_x_train, feature_ext)
df_x_test_exp = feature_expansion(df_x_test, feature_ext)

x_train = np.expand_dims(df_x_train_exp, 1)
x_test = np.expand_dims(df_x_test_exp, 1)

y_train = pd.get_dummies(y_train).values
y_test = pd.get_dummies(y_test).values
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:13<00:00, 75.80it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 80.08it/s]

# %% [markdown]
# # Model RNN

# %%
def RNN(x_train_c, y_train_c, x_test_c, y_test_c):
    rnn = Sequential()
    rnn.add(SimpleRNN(units=256, activation='relu', recurrent_dropout=0.2, return_sequences=True))
    rnn.add(Dropout(0.2))
    rnn.add(SimpleRNN(units=128, activation='relu', return_sequences=True))
    rnn.add(Dropout(0.2))
    rnn.add(SimpleRNN(units=64, activation='relu'))
    rnn.add(Dropout(0.2))
    rnn.add(Dense(units=3, activation='softmax'))
    
    rnn.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    rnn.build(x_train_c.shape)
    
    early_stopping = EarlyStopping(monitor='val_loss', mode = 'min', verbose = 1, patience=3, min_delta=0.0001)
    model_checkpoint = ModelCheckpoint('rnn_tfidf_ft_smote_akting.h5', monitor = 'val_accuracy', mode = 'max', verbose = 1, save_best_only = True)
    
    history = rnn.fit(x_train_c, y_train_c, epochs= 10, batch_size=128, 
                      validation_data=(x_test_c, y_test_c), verbose = 1,
                      callbacks=[early_stopping, model_checkpoint])
    
    model = load_model('rnn_tfidf_ft_smote_akting.h5')
    y_pred = model.predict(x_test_c)
    y_pred_cat = y_pred.argmax(axis=1)
    y_test_cat = np.argmax(y_test_c, axis=1)
   
    cm = confusion_matrix(y_test_cat, y_pred_cat)
    classreport = classification_report(y_test_cat, y_pred_cat)
    f1 = f1_score(y_test_cat, y_pred_cat,  average="macro")
    recall = recall_score(y_test_cat, y_pred_cat, average="macro")
    precision = precision_score(y_test_cat, y_pred_cat, average="macro")
    accuracy = accuracy_score(y_test_cat, y_pred_cat)

    print(classreport)
    print("F1 Score : ", f1)
    print("Precision : ", precision)
    print("Recall : ", recall)
    print("Accuracy : ", accuracy)

    return [f1, precision, recall, accuracy, cm]

# %% [markdown]
# # Running

# %%
hasil = []

for i in range(1, 6):
    hasil.append([str(i)] + RNN(x_train, y_train, x_test, y_test))
# Out:
# Epoch 1/10
# 220/226 [============================>.] - ETA: 0s - loss: 0.5136 - accuracy: 0.7974
# Epoch 1: val_accuracy improved from -inf to 0.91511, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 6s 12ms/step - loss: 0.5075 - accuracy: 0.8001 - val_loss: 0.2467 - val_accuracy: 0.9151
# Epoch 2/10
# 223/226 [============================>.] - ETA: 0s - loss: 0.2033 - accuracy: 0.9324
# Epoch 2: val_accuracy improved from 0.91511 to 0.94360, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.2029 - accuracy: 0.9325 - val_loss: 0.1685 - val_accuracy: 0.9436
# Epoch 3/10
# 221/226 [============================>.] - ETA: 0s - loss: 0.1312 - accuracy: 0.9573
# Epoch 3: val_accuracy improved from 0.94360 to 0.95675, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.1302 - accuracy: 0.9576 - val_loss: 0.1337 - val_accuracy: 0.9567
# Epoch 4/10
# 223/226 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9720
# Epoch 4: val_accuracy improved from 0.95675 to 0.96482, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0867 - accuracy: 0.9721 - val_loss: 0.1137 - val_accuracy: 0.9648
# Epoch 5/10
# 224/226 [============================>.] - ETA: 0s - loss: 0.0654 - accuracy: 0.9796
# Epoch 5: val_accuracy did not improve from 0.96482
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0655 - accuracy: 0.9796 - val_loss: 0.1217 - val_accuracy: 0.9631
# Epoch 6/10
# 219/226 [============================>.] - ETA: 0s - loss: 0.0523 - accuracy: 0.9834
# Epoch 6: val_accuracy did not improve from 0.96482
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0522 - accuracy: 0.9834 - val_loss: 0.1271 - val_accuracy: 0.9636
# Epoch 7/10
# 223/226 [============================>.] - ETA: 0s - loss: 0.0427 - accuracy: 0.9866
# Epoch 7: val_accuracy did not improve from 0.96482
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0428 - accuracy: 0.9865 - val_loss: 0.1416 - val_accuracy: 0.9602
# Epoch 7: early stopping
# 388/388 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4131
#            1       0.96      0.94      0.95      4131
#            2       0.95      0.96      0.95      4131
#
#     accuracy                           0.96     12393
#    macro avg       0.96      0.96      0.96     12393
# weighted avg       0.96      0.96      0.96     12393
#
# F1 Score :  0.9647155039767698
# Precision :  0.9647087172744103
# Recall :  0.9648188493504398
# Accuracy :  0.9648188493504397
# Epoch 1/10
# 224/226 [============================>.] - ETA: 0s - loss: 0.5169 - accuracy: 0.7970
# Epoch 1: val_accuracy improved from -inf to 0.91156, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 5s 11ms/step - loss: 0.5157 - accuracy: 0.7976 - val_loss: 0.2606 - val_accuracy: 0.9116
# Epoch 2/10
# 217/226 [===========================>..] - ETA: 0s - loss: 0.2124 - accuracy: 0.9276
# Epoch 2: val_accuracy improved from 0.91156 to 0.94731, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.2113 - accuracy: 0.9279 - val_loss: 0.1600 - val_accuracy: 0.9473
# Epoch 3/10
# 221/226 [============================>.] - ETA: 0s - loss: 0.1304 - accuracy: 0.9567
# Epoch 3: val_accuracy improved from 0.94731 to 0.95126, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.1302 - accuracy: 0.9566 - val_loss: 0.1418 - val_accuracy: 0.9513
# Epoch 4/10
# 226/226 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9716
# Epoch 4: val_accuracy improved from 0.95126 to 0.96385, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0865 - accuracy: 0.9716 - val_loss: 0.1115 - val_accuracy: 0.9639
# Epoch 5/10
# 221/226 [============================>.] - ETA: 0s - loss: 0.0675 - accuracy: 0.9789
# Epoch 5: val_accuracy did not improve from 0.96385
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0670 - accuracy: 0.9789 - val_loss: 0.1213 - val_accuracy: 0.9615
# Epoch 6/10
# 217/226 [===========================>..] - ETA: 0s - loss: 0.0544 - accuracy: 0.9832
# Epoch 6: val_accuracy did not improve from 0.96385
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0549 - accuracy: 0.9830 - val_loss: 0.1407 - val_accuracy: 0.9584
# Epoch 7/10
# 220/226 [============================>.] - ETA: 0s - loss: 0.0399 - accuracy: 0.9873
# Epoch 7: val_accuracy did not improve from 0.96385
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0397 - accuracy: 0.9874 - val_loss: 0.1372 - val_accuracy: 0.9617
# Epoch 7: early stopping
# 388/388 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      4131
#            1       0.95      0.94      0.95      4131
#            2       0.95      0.95      0.95      4131
#
#     accuracy                           0.96     12393
#    macro avg       0.96      0.96      0.96     12393
# weighted avg       0.96      0.96      0.96     12393
#
# F1 Score :  0.963767983483275
# Precision :  0.9637309227028386
# Recall :  0.9638505608004518
# Accuracy :  0.9638505608004518
# Epoch 1/10
# 226/226 [==============================] - ETA: 0s - loss: 0.5177 - accuracy: 0.7930
# Epoch 1: val_accuracy improved from -inf to 0.91665, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 5s 12ms/step - loss: 0.5177 - accuracy: 0.7930 - val_loss: 0.2541 - val_accuracy: 0.9166
# Epoch 2/10
# 225/226 [============================>.] - ETA: 0s - loss: 0.2076 - accuracy: 0.9324
# Epoch 2: val_accuracy improved from 0.91665 to 0.94949, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.2071 - accuracy: 0.9326 - val_loss: 0.1512 - val_accuracy: 0.9495
# Epoch 3/10
# 219/226 [============================>.] - ETA: 0s - loss: 0.1302 - accuracy: 0.9581
# Epoch 3: val_accuracy improved from 0.94949 to 0.95578, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.1303 - accuracy: 0.9579 - val_loss: 0.1317 - val_accuracy: 0.9558
# Epoch 4/10
# 225/226 [============================>.] - ETA: 0s - loss: 0.0874 - accuracy: 0.9726
# Epoch 4: val_accuracy improved from 0.95578 to 0.95844, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0875 - accuracy: 0.9725 - val_loss: 0.1312 - val_accuracy: 0.9584
# Epoch 5/10
# 217/226 [===========================>..] - ETA: 0s - loss: 0.0648 - accuracy: 0.9788
# Epoch 5: val_accuracy improved from 0.95844 to 0.96466, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0645 - accuracy: 0.9789 - val_loss: 0.1178 - val_accuracy: 0.9647
# Epoch 6/10
# 217/226 [===========================>..] - ETA: 0s - loss: 0.0540 - accuracy: 0.9826
# Epoch 6: val_accuracy improved from 0.96466 to 0.96692, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 7ms/step - loss: 0.0535 - accuracy: 0.9829 - val_loss: 0.1193 - val_accuracy: 0.9669
# Epoch 7/10
# 220/226 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.9861
# Epoch 7: val_accuracy did not improve from 0.96692
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0427 - accuracy: 0.9861 - val_loss: 0.1220 - val_accuracy: 0.9654
# Epoch 8/10
# 220/226 [============================>.] - ETA: 0s - loss: 0.0354 - accuracy: 0.9885
# Epoch 8: val_accuracy did not improve from 0.96692
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0353 - accuracy: 0.9886 - val_loss: 0.1308 - val_accuracy: 0.9655
# Epoch 8: early stopping
# 388/388 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4131
#            1       0.96      0.95      0.95      4131
#            2       0.96      0.95      0.96      4131
#
#     accuracy                           0.97     12393
#    macro avg       0.97      0.97      0.97     12393
# weighted avg       0.97      0.97      0.97     12393
#
# F1 Score :  0.9668263936491703
# Precision :  0.9667924523433479
# Recall :  0.9669168078754136
# Accuracy :  0.9669168078754136
# Epoch 1/10
# 218/226 [===========================>..] - ETA: 0s - loss: 0.5182 - accuracy: 0.7957
# Epoch 1: val_accuracy improved from -inf to 0.90874, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 5s 11ms/step - loss: 0.5091 - accuracy: 0.7999 - val_loss: 0.2640 - val_accuracy: 0.9087
# Epoch 2/10
# 220/226 [============================>.] - ETA: 0s - loss: 0.2131 - accuracy: 0.9279
# Epoch 2: val_accuracy improved from 0.90874 to 0.93617, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.2122 - accuracy: 0.9284 - val_loss: 0.1809 - val_accuracy: 0.9362
# Epoch 3/10
# 226/226 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9590
# Epoch 3: val_accuracy improved from 0.93617 to 0.95489, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.1271 - accuracy: 0.9590 - val_loss: 0.1341 - val_accuracy: 0.9549
# Epoch 4/10
# 220/226 [============================>.] - ETA: 0s - loss: 0.0910 - accuracy: 0.9706
# Epoch 4: val_accuracy improved from 0.95489 to 0.95796, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0912 - accuracy: 0.9707 - val_loss: 0.1294 - val_accuracy: 0.9580
# Epoch 5/10
# 220/226 [============================>.] - ETA: 0s - loss: 0.0637 - accuracy: 0.9792
# Epoch 5: val_accuracy improved from 0.95796 to 0.96304, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0637 - accuracy: 0.9792 - val_loss: 0.1186 - val_accuracy: 0.9630
# Epoch 6/10
# 221/226 [============================>.] - ETA: 0s - loss: 0.0508 - accuracy: 0.9833
# Epoch 6: val_accuracy improved from 0.96304 to 0.96619, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0513 - accuracy: 0.9832 - val_loss: 0.1155 - val_accuracy: 0.9662
# Epoch 7/10
# 218/226 [===========================>..] - ETA: 0s - loss: 0.0461 - accuracy: 0.9853
# Epoch 7: val_accuracy did not improve from 0.96619
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0460 - accuracy: 0.9854 - val_loss: 0.1355 - val_accuracy: 0.9644
# Epoch 8/10
# 222/226 [============================>.] - ETA: 0s - loss: 0.0354 - accuracy: 0.9887
# Epoch 8: val_accuracy improved from 0.96619 to 0.96756, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0353 - accuracy: 0.9887 - val_loss: 0.1196 - val_accuracy: 0.9676
# Epoch 9/10
# 218/226 [===========================>..] - ETA: 0s - loss: 0.0273 - accuracy: 0.9913
# Epoch 9: val_accuracy did not improve from 0.96756
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0279 - accuracy: 0.9912 - val_loss: 0.1327 - val_accuracy: 0.9673
# Epoch 9: early stopping
# 388/388 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      4131
#            1       0.96      0.95      0.95      4131
#            2       0.95      0.96      0.96      4131
#
#     accuracy                           0.97     12393
#    macro avg       0.97      0.97      0.97     12393
# weighted avg       0.97      0.97      0.97     12393
#
# F1 Score :  0.9675079678599415
# Precision :  0.9675336580232612
# Recall :  0.9675623335754056
# Accuracy :  0.9675623335754054
# Epoch 1/10
# 217/226 [===========================>..] - ETA: 0s - loss: 0.5122 - accuracy: 0.7971
# Epoch 1: val_accuracy improved from -inf to 0.91511, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 5s 12ms/step - loss: 0.5044 - accuracy: 0.8007 - val_loss: 0.2498 - val_accuracy: 0.9151
# Epoch 2/10
# 216/226 [===========================>..] - ETA: 0s - loss: 0.2034 - accuracy: 0.9319
# Epoch 2: val_accuracy improved from 0.91511 to 0.94408, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.2015 - accuracy: 0.9325 - val_loss: 0.1609 - val_accuracy: 0.9441
# Epoch 3/10
# 221/226 [============================>.] - ETA: 0s - loss: 0.1267 - accuracy: 0.9575
# Epoch 3: val_accuracy improved from 0.94408 to 0.95263, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.1266 - accuracy: 0.9577 - val_loss: 0.1401 - val_accuracy: 0.9526
# Epoch 4/10
# 217/226 [===========================>..] - ETA: 0s - loss: 0.0875 - accuracy: 0.9713
# Epoch 4: val_accuracy improved from 0.95263 to 0.96078, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0881 - accuracy: 0.9711 - val_loss: 0.1212 - val_accuracy: 0.9608
# Epoch 5/10
# 219/226 [============================>.] - ETA: 0s - loss: 0.0768 - accuracy: 0.9754
# Epoch 5: val_accuracy improved from 0.96078 to 0.96175, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0761 - accuracy: 0.9756 - val_loss: 0.1186 - val_accuracy: 0.9618
# Epoch 6/10
# 226/226 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9847
# Epoch 6: val_accuracy improved from 0.96175 to 0.96659, saving model to rnn_tfidf_ft_smote_akting.h5
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0508 - accuracy: 0.9847 - val_loss: 0.1136 - val_accuracy: 0.9666
# Epoch 7/10
# 221/226 [============================>.] - ETA: 0s - loss: 0.0401 - accuracy: 0.9875
# Epoch 7: val_accuracy did not improve from 0.96659
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0397 - accuracy: 0.9876 - val_loss: 0.1371 - val_accuracy: 0.9641
# Epoch 8/10
# 216/226 [===========================>..] - ETA: 0s - loss: 0.0327 - accuracy: 0.9895
# Epoch 8: val_accuracy did not improve from 0.96659
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0330 - accuracy: 0.9893 - val_loss: 0.1360 - val_accuracy: 0.9643
# Epoch 9/10
# 226/226 [==============================] - ETA: 0s - loss: 0.0318 - accuracy: 0.9896
# Epoch 9: val_accuracy did not improve from 0.96659
# 226/226 [==============================] - 1s 6ms/step - loss: 0.0318 - accuracy: 0.9896 - val_loss: 0.1436 - val_accuracy: 0.9631
# Epoch 9: early stopping
# 388/388 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4131
#            1       0.96      0.94      0.95      4131
#            2       0.96      0.96      0.96      4131
#
#     accuracy                           0.97     12393
#    macro avg       0.97      0.97      0.97     12393
# weighted avg       0.97      0.97      0.97     12393
#
# F1 Score :  0.966503299099028
# Precision :  0.9664867062913056
# Recall :  0.9665940450254175
# Accuracy :  0.9665940450254176

# %% [markdown]
# # Save Output

# %%
df = pd.DataFrame(hasil, columns =['iterasi', 'f1', 'precision', 'recall', 'accuracy', 'cm'])
#df.to_excel('rnn_tfidf_ft_smote_akting.xlsx')
df.head()
# Out:
#   iterasi        f1  precision    recall  accuracy  \
# 0       1  0.964716   0.964709  0.964819  0.964819
# 1       2  0.963768   0.963731  0.963851  0.963851
# 2       3  0.966826   0.966792  0.966917  0.966917
# 3       4  0.967508   0.967534  0.967562  0.967562
# 4       5  0.966503   0.966487  0.966594  0.966594
#
#                                                   cm
# 0   [[4123, 4, 4], [46, 3888, 197], [24, 161, 3946]]
# 1  [[4117, 13, 1], [39, 3894, 198], [23, 174, 3934]]
# 2   [[4123, 8, 0], [55, 3918, 158], [16, 173, 3942]]
# 3  [[4113, 7, 11], [34, 3907, 190], [18, 142, 3971]]
# 4  [[4121, 10, 0], [49, 3898, 184], [16, 155, 3960]]

# %%
print("Accuracy : %.2f" % (df['accuracy'].mean()*100))
print("F1-Score : %.2f" % (df['f1'].mean()*100))
# Out:
# Accuracy : 96.59
# F1-Score : 96.59
